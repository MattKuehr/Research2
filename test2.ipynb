# %%
from original_code.config import get_config
from original_code.params import get_params
from utils import get_points_array
import numpy as np
import json

# %% [markdown]
# Include this ComplexEncoder in the new data generation notebook for the sample json objects

# %%
class ComplexEncoder(json.JSONEncoder):
    def default(self, obj):
        if isinstance(obj, complex):
            return [obj.real, obj.imag]
